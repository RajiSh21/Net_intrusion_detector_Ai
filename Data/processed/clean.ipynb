# %%
import pandas as pd

df = pd.read_csv(r"E:\Nid\Data\raw\IDS2025.csv")

# %%
print(df.shape)
print(df.columns.tolist())                          #   see all column name 
print(df['newLabel'].value_counts())                #   class distribution
print(df.info())                                    #   data types + missing
print(df.describe())                                #   stats for numeric columns
# Out:
# (91744, 80)
# ...

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')

# %%
df.isnull().sum()
missing = df.isnull().sum()
print(missing[missing > 0])               #only show columns with missing values
# Out:
# flow_bytess    77
# dtype: int64
